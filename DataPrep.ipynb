# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pickle as pkl
import glob
import numpy as np
import cv2
from img_load import load_bimg
from NPSmethods2 import *

# %%
psat=277

#Settings of imaging system
imgSysData = { 
    "CCDPixelSize": 13,      # pixel size of the CCD, in micron 
    "magnification": 27,      # 799.943 / 29.9099, # magnification of the imaging system 
    "wavelen"     : 0.852,     # wavelength of the imaging beam, in micron 
    "NA"          : 0.37,      # numerical aperture of the objective 
    "ODtoAtom"    : 13
}

#Configurations for NPSMethods (here we only need do_Fit)
choices = {
    "if_Save"                     : True,
    "do_Fit"                      : True,
    "plot_2dGas"                  : False,
    "plot_NoisePowSpec"           : True,
    "plot_NoisePowSpec_LineCut"   : True,
    "plot_Pupil"                  : False,
    "plot_PSF"                    : False,
    "plot_PSF_LineCut"            : False,
    "plot_PSF_abs2"               : False,
    "plot_PSF_abs2_LineCut"       : False,
    "plot_Sk"                     : False,
    "normalize"                   : False
}

#Directory containing image folders
path = r'C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image'

#Directory where ML data will output to
resDir = r'C:\Users\eric0\Jupyter Notebooks\Cold Physics\results'

trapRegion = (slice(100, 200), slice(100, 200))
    # the region where the atoms located, [(xmin, xmax), (ymin, ymax)] (pixel)

noiseRegion = (slice(0, 300), slice(0, 300))
    # the region chosen for noise analysis, [(xmin, xmax), (ymin, ymax)] (pixel)

numOfImgsInEachRun = 50      # number of images for each run of analysis

rampingParameter = 0

#Lists where OD images and parameters will be stored
rawimages = []
parameters = []

#Sort through folders in path directory for raw images, extract OD image and parameters, then append to lists
for folder in glob.iglob(path + "\\*"):
    result=load_bimg(folder + "\\", raw=True)
    odimg=-np.log(result['raw1']/result['raw2'])-(result['raw1']-result['raw2'])/psat
    _, _, _, _, popt, _ = doCalibration(folder, resDir, trapRegion, noiseRegion, numOfImgsInEachRun, rampingParameter, imgSysData, choices)
    print(popt)
    for i in range(len(odimg)):
        rawimages.append(odimg[i])
        parameters.append(popt)
# Out:
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\031550\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0000 : spherical aberration
# alpha   =  2.2993 : astigmatism
# beta    =  0.5708 : defocus
# delta_s = -0.1162 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 3.00000000e-01  1.00000000e+00  1.37312740e-31  2.29929184e+00
#  -1.92862366e+00  5.70828886e-01 -1.16154442e-01]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\051352\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0100 : spherical aberration
# alpha   =  2.3192 : astigmatism
# beta    =  0.5329 : defocus
# delta_s = -0.0325 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 0.23999081  1.          0.01        2.31915657 -1.89718388  0.53287932
#  -0.03250217]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\141147\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0000 : spherical aberration
# alpha   =  2.4600 : astigmatism
# beta    = -2.0000 : defocus
# delta_s = -0.1055 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 2.15445970e-01  1.00000000e+00  1.60460052e-22  2.46000000e+00
#  -1.88572246e+00 -2.00000000e+00 -1.05513813e-01]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\141153\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0000 : spherical aberration
# alpha   =  2.4600 : astigmatism
# beta    = -1.7309 : defocus
# delta_s = -0.0049 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 2.14988584e-01  1.00000000e+00  3.32499404e-14  2.46000000e+00
#  -1.89439248e+00 -1.73089208e+00 -4.86250690e-03]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\141201\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0000 : spherical aberration
# alpha   =  2.4600 : astigmatism
# beta    = -0.7717 : defocus
# delta_s =  0.0059 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 2.26818663e-01  1.00000000e+00  4.37659357e-09  2.46000000e+00
#  -1.88637778e+00 -7.71679074e-01  5.87082542e-03]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\141206\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0000 : spherical aberration
# alpha   =  2.4600 : astigmatism
# beta    = -0.2539 : defocus
# delta_s =  0.0210 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 2.44297090e-01  1.00000000e+00  1.01035120e-16  2.46000000e+00
#  -1.89571484e+00 -2.53949236e-01  2.09779702e-02]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\151033\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0000 : spherical aberration
# alpha   =  2.4600 : astigmatism
# beta    = -1.7372 : defocus
# delta_s =  0.0322 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 2.93528810e-01  1.00000000e+00  1.22047012e-10  2.46000000e+00
#  -1.87173512e+00 -1.73716670e+00  3.22022415e-02]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\151038\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0000 : spherical aberration
# alpha   =  2.4185 : astigmatism
# beta    = -0.9083 : defocus
# delta_s = -0.0084 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 2.81170941e-01  1.00000000e+00  8.74686942e-18  2.41853270e+00
#  -1.87981526e+00 -9.08310409e-01 -8.39567330e-03]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\151413\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0100 : spherical aberration
# alpha   =  2.4600 : astigmatism
# beta    =  0.5302 : defocus
# delta_s = -0.0352 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 0.25384914  1.          0.00999999  2.46       -1.89497174  0.53016181
#  -0.0352161 ]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\151418\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0000 : spherical aberration
# alpha   =  2.4600 : astigmatism
# beta    = -0.3163 : defocus
# delta_s =  0.0452 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 2.43612150e-01  1.00000000e+00  1.92138315e-14  2.46000000e+00
#  -1.88440384e+00 -3.16289754e-01  4.51755040e-02]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\191450\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0100 : spherical aberration
# alpha   =  2.4600 : astigmatism
# beta    =  1.3655 : defocus
# delta_s = -0.1213 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 0.25211384  1.          0.01        2.46       -1.89066062  1.36552705
#  -0.12128537]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\191454\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0000 : spherical aberration
# alpha   =  2.1814 : astigmatism
# beta    = -0.2861 : defocus
# delta_s = -0.0799 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 2.28471092e-01  1.00000000e+00  1.65364494e-22  2.18138551e+00
#  -1.90029073e+00 -2.86100109e-01 -7.99019162e-02]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\191457\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0100 : spherical aberration
# alpha   =  2.0877 : astigmatism
# beta    =  0.2015 : defocus
# delta_s = -0.0904 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 0.26607456  1.          0.01        2.08773815 -1.93656095  0.20154247
#  -0.09040644]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\211513\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0000 : spherical aberration
# alpha   =  2.3089 : astigmatism
# beta    =  0.1487 : defocus
# delta_s = -0.1346 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 3.00000000e-01  1.00000000e+00  3.46932291e-37  2.30893477e+00
#  -1.89411110e+00  1.48701785e-01 -1.34559209e-01]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\221119\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0100 : spherical aberration
# alpha   =  2.4600 : astigmatism
# beta    = -1.7850 : defocus
# delta_s =  0.0038 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 0.24388801  1.          0.01        2.46       -1.89784517 -1.78497869
#   0.00384222]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\221124\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0000 : spherical aberration
# alpha   =  2.3318 : astigmatism
# beta    = -0.2150 : defocus
# delta_s = -0.0223 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 2.55654505e-01  1.00000000e+00  5.73677937e-16  2.33176046e+00
#  -1.89476948e+00 -2.15029302e-01 -2.22737755e-02]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\221524\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0000 : spherical aberration
# alpha   =  2.4600 : astigmatism
# beta    =  1.8646 : defocus
# delta_s = -0.1774 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 3.00000000e-01  1.00000000e+00  1.06749999e-27  2.46000000e+00
#  -1.87544533e+00  1.86464304e+00 -1.77375226e-01]
# load data from C:\Users\eric0\Jupyter Notebooks\Cold Physics\raw_image\221529\
# od size (0,)
# tau     =  1.0000 : describe the decaying of transmission efficiency with radius
# S0      =  0.0000 : spherical aberration
# alpha   =  2.4430 : astigmatism
# beta    =  0.3960 : defocus
# delta_s = -0.0682 : phase imprint by atom scattering
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:707: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Exp = ax_NPS_Exp.pcolor(K_x, K_y, M2k_Exp, cmap=cMap, vmin=vMin_Exp, vmax=vMax_Exp)
# C:\Users\eric0\Jupyter Notebooks\Cold Physics\NPSmethods2.py:717: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc_NPS_Fit = ax_NPS_Fit.pcolor(K_x, K_y, M2k_Fit, cmap=cMap, vmin=vMin_Fit, vmax=vMax_Fit)
# [ 3.00000000e-01  1.00000000e+00  5.30194635e-38  2.44297368e+00
#  -1.90286538e+00  3.96041349e-01 -6.81521929e-02]

# %%
seedParasMax = np.empty_like(parameters[0])
seedParasMin = np.empty_like(parameters[0])
rotparam = np.array(parameters).T
for i in range(len(parameters[0])):
    seedParasMax[i] = np.max(rotparam[i])
    seedParasMin[i] = np.min(rotparam[i])

# %%
print(seedParasMax)
print(seedParasMin)
# Out:
# [ 0.3         1.          0.01        2.46       -1.87173512  1.86464304
#   0.0451755 ]
# [ 2.14988584e-01  1.00000000e+00  5.30194635e-38  2.08773815e+00
#  -1.93656095e+00 -2.00000000e+00 -1.77375226e-01]

# %%
pkl.dump(seedParasMin, open(resDir + "\\seedParasMin.pkl", "wb"))
pkl.dump(seedParasMax, open(resDir + "\\seedParasMax.pkl", "wb"))

# %%
# #Scale data and split into training and validation sets as arrays
# scaler = StandardScaler()
# yscaler = scaler.fit(np.array(parameters))
# scaledpara = scaler.transform(np.array(parameters))
# rawimages = np.array(rawimages).reshape((147,-1))
# trainin, testin, trainout, testout = train_test_split(rawimages, scaledpara, test_size=0.25, shuffle=True)

# %%
# #Store ML training data as pickle files
# pkl.dump(trainin, open(resDir + "\\trainin.pkl", "wb"))
# pkl.dump(trainout, open(resDir + "\\trainout.pkl", "wb"))
# pkl.dump(testin, open(resDir + "\\testin.pkl", "wb"))
# pkl.dump(testout, open(resDir + "\\testout.pkl", "wb"))
# pkl.dump(yscaler, open(resDir + "\\yscaler.pkl", "wb"))
